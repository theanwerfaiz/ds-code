# %%
#import the library Pandas
import pandas as pd

# %%
#Put the lendingdata.csv dataset on Root Directory
#Read the dataset 
data = pd.read_csv('lendingdata.csv')

# %%
#Showing the 5 Data of given dataset
data
# Out:
#        Unnamed: 0                        activity borrower_genders  \
# 0               0                 Home Appliances            group
# 1               1                         Cereals           female
# 2               2                  Clothing Sales           female
# 3               3                  Clothing Sales           female
# 4               4                    Fish Selling           female
# 5               5         Personal Products Sales           female
# 6               6                  Transportation             male
# 7               7                 Home Appliances            group
# 8               8                          Bakery             male
# 9               9                         Farming             male
# 10             10  Primary/secondary school costs           female
# 11             11           Construction Supplies           female
# 12             12                          Retail           female
# 13             13         Personal Products Sales           female
# 14             14                 Cosmetics Sales           female
# 15             15          Higher education costs           female
# 16             16                   General Store             male
# 17             17                          Retail           female
# 18             18                         Farming            group
# 19             19                   Used Clothing           female
# 20             20       Personal Housing Expenses            group
# 21             21                         Farming            group
# 22             22                   Manufacturing           female
# 23             23                         Farming             male
# 24             24                   Cheese Making           female
# 25             25                          Cattle              NaN
# 26             26          Higher education costs           female
# 27             27       Personal Housing Expenses           female
# 28             28                         Farming           female
# 29             29                            Food           female
# ...           ...                             ...              ...
# 27506       27506                             NaN           female
# 27507       27507             Fruits & Vegetables           female
# 27508       27508                          Retail           female
# 27509       27509                   Grocery Store             male
# 27510       27510                            Pigs            group
# 27511       27511                   Grocery Store           female
# 27512       27512                        Services           female
# 27513       27513                           Dairy           female
# 27514       27514                            Pigs             male
# 27515       27515                     Agriculture           female
# 27516       27516                          Retail            group
# 27517       27517               Electronics Sales           female
# 27518       27518                            Food            group
# 27519       27519                   Grocery Store           female
# 27520       27520                          Retail           female
# 27521       27521            Motorcycle Transport           female
# 27522       27522                   General Store           female
# 27523       27523                          Crafts             male
# 27524       27524                         Farming            group
# 27525       27525           Food Production/Sales           female
# 27526       27526                   Farm Supplies             male
# 27527       27527                            Food            group
# 27528       27528                       Beverages           female
# 27529       27529                   Grocery Store           female
# 27530       27530                  Transportation             male
# 27531       27531                        Services           female
# 27532       27532                            Pigs           female
# 27533       27533                   General Store           female
# 27534       27534                     Food Market           female
# 27535       27535                         Farming             male
#
#              country country_code currency_policy distribution_model  \
# 0           Cambodia           KH          shared      field_partner
# 1        Philippines           PH          shared      field_partner
# 2               Peru           PE          shared      field_partner
# 3         Tajikistan           TJ      not shared      field_partner
# 4             Uganda           UG      not shared      field_partner
# 5             Jordan           JO          shared      field_partner
# 6         Tajikistan           TJ      not shared      field_partner
# 7           Cambodia           KH          shared      field_partner
# 8          Nicaragua           NI          shared      field_partner
# 9            Nigeria           NG          shared      field_partner
# 10          Colombia           CO      not shared      field_partner
# 11         Nicaragua           NI          shared      field_partner
# 12          Colombia           CO      not shared      field_partner
# 13       Philippines           PH      not shared      field_partner
# 14           Ecuador           EC      not shared      field_partner
# 15          Colombia           CO          shared      field_partner
# 16          Honduras           HN          shared      field_partner
# 17             Benin           BJ          shared      field_partner
# 18          Cambodia           KH          shared      field_partner
# 19         Nicaragua           NI      not shared      field_partner
# 20            Uganda           UG      not shared      field_partner
# 21          Cambodia           KH          shared      field_partner
# 22       Philippines           PH          shared      field_partner
# 23           Ecuador           EC      not shared      field_partner
# 24            Jordan           JO          shared      field_partner
# 25        Tajikistan           TJ      not shared      field_partner
# 26          Cambodia           KH          shared      field_partner
# 27         Indonesia           ID          shared      field_partner
# 28       Philippines           PH          shared      field_partner
# 29             Kenya           KE          shared      field_partner
# ...              ...          ...             ...                ...
# 27506    Philippines           PH          shared      field_partner
# 27507    Philippines           PH          shared      field_partner
# 27508        Liberia           LR          shared      field_partner
# 27509          Kenya           KE          shared      field_partner
# 27510       Cambodia           KH          shared      field_partner
# 27511          Kenya           KE          shared      field_partner
# 27512  United States           US      not shared      field_partner
# 27513          Kenya           KE          shared      field_partner
# 27514      Nicaragua           NI          shared      field_partner
# 27515    El Salvador           SV          shared      field_partner
# 27516            NaN           PE          shared      field_partner
# 27517    Philippines           PH          shared      field_partner
# 27518           Peru           PE          shared      field_partner
# 27519      Indonesia           ID      not shared      field_partner
# 27520          Benin           BJ          shared      field_partner
# 27521    Philippines           PH          shared      field_partner
# 27522    Philippines           PH          shared      field_partner
# 27523    El Salvador           SV          shared                NaN
# 27524       Cambodia           KH          shared      field_partner
# 27525       Cambodia           KH      not shared      field_partner
# 27526    El Salvador           SV          shared      field_partner
# 27527          Ghana           GH          shared      field_partner
# 27528      Nicaragua           NI      not shared      field_partner
# 27529           Peru           PE      not shared      field_partner
# 27530           Peru           PE          shared      field_partner
# 27531         Zambia           ZM          shared      field_partner
# 27532    Philippines           PH      not shared      field_partner
# 27533    Philippines           PH          shared      field_partner
# 27534          Ghana           GH          shared      field_partner
# 27535     Tajikistan           TJ      not shared      field_partner
#
#        lender_count  loan_amount original_language repayment_interval  \
# 0               5.0        125.0           English            monthly
# 1               5.0        125.0           English          irregular
# 2              10.0        375.0           Spanish            monthly
# 3              27.0        850.0           English            monthly
# 4              17.0        550.0           English          irregular
# 5              22.0        575.0           English            monthly
# 6              38.0       1125.0           English          irregular
# 7               4.0        100.0           English            monthly
# 8              17.0       1400.0           Spanish            monthly
# 9              19.0        600.0           English             bullet
# 10             12.0        325.0           Spanish          irregular
# 11             14.0        400.0           Spanish            monthly
# 12             40.0       1025.0           Spanish            monthly
# 13             17.0        450.0           English          irregular
# 14             26.0       1650.0           Spanish          irregular
# 15              9.0        225.0           Spanish            monthly
# 16             29.0        775.0           Spanish            monthly
# 17             13.0       1025.0            French            monthly
# 18             36.0       1000.0           English            monthly
# 19             12.0        325.0           Spanish            monthly
# 20             89.0       2400.0           English            monthly
# 21             25.0        700.0           English            monthly
# 22              8.0        225.0           English          irregular
# 23             21.0        600.0           Spanish             bullet
# 24             44.0       1175.0           English            monthly
# 25             53.0       1850.0           English          irregular
# 26             52.0       1450.0           English            monthly
# 27              2.0        525.0           English          irregular
# 28              8.0        200.0           English          irregular
# 29              1.0        100.0           English            monthly
# ...             ...          ...               ...                ...
# 27506          12.0        450.0           English          irregular
# 27507           1.0        200.0           English          irregular
# 27508           9.0        225.0           English          irregular
# 27509          13.0        375.0           English          irregular
# 27510          20.0        750.0           English                NaN
# 27511          16.0        400.0           English          irregular
# 27512          92.0       4775.0           English            monthly
# 27513          15.0        700.0           English            monthly
# 27514          34.0       1100.0           Spanish            monthly
# 27515          20.0        500.0           Spanish             bullet
# 27516           2.0       3225.0           Spanish          irregular
# 27517           7.0        175.0           English          irregular
# 27518         123.0       3625.0           Spanish          irregular
# 27519           4.0        100.0           English            monthly
# 27520           8.0        225.0            French            monthly
# 27521          10.0        250.0           English          irregular
# 27522           5.0        125.0           English            monthly
# 27523          35.0       1500.0           Spanish            monthly
# 27524          30.0        750.0           English            monthly
# 27525          27.0       1000.0           English            monthly
# 27526          15.0        500.0           Spanish             bullet
# 27527         111.0       3475.0           English          irregular
# 27528          16.0        400.0           Spanish            monthly
# 27529          27.0        725.0           Spanish          irregular
# 27530          16.0       1025.0           Spanish          irregular
# 27531          85.0       2300.0           English             bullet
# 27532          17.0        475.0           English          irregular
# 27533          38.0       1075.0           English          irregular
# 27534          35.0       1075.0           English          irregular
# 27535          55.0       2000.0           English            monthly
#
#                sector      status term_in_months   rMPI
# 0        Personal Use      funded              8  0.097
# 1                Food      funded             14  0.055
# 2            Clothing      funded              8  0.000
# 3            Clothing      funded             14  0.021
# 4                Food      funded              9  0.417
# 5              Retail      funded             15  0.005
# 6      Transportation      funded              6  0.033
# 7        Personal Use      funded              8  0.120
# 8                Food  not_funded             20  0.161
# 9         Agriculture      funded             19  0.311
# 10          Education      funded              7  0.009
# 11       Construction      funded             15  0.112
# 12             Retail      funded             17  0.009
# 13             Retail      funded              8  0.422
# 14             Retail      funded              8  0.054
# 15          Education      funded              4  0.583
# 16             Retail      funded         1 Year  0.112
# 17             Retail  not_funded             14  0.083
# 18        Agriculture      funded             14  0.274
# 19           Clothing      funded             13  0.161
# 20            Housing      funded             14  0.013
# 21        Agriculture      funded             14  0.274
# 22      Manufacturing      funded              7  0.039
# 23        Agriculture      funded             11  0.014
# 24               Food      funded             21  0.005
# 25        Agriculture      funded             14  0.021
# 26          Education      funded             50  0.274
# 27            Housing  not_funded             59  0.029
# 28        Agriculture      funded              7  0.055
# 29               Food      funded              8  0.075
# ...               ...         ...            ...    ...
# 27506        Services      funded              5  0.422
# 27507            Food      funded              8  0.055
# 27508          Retail      funded         1 Year  0.214
# 27509            Food      funded             14  0.075
# 27510     Agriculture      funded             14  0.097
# 27511            Food      funded             13  0.075
# 27512        Services      funded             26  0.382
# 27513     Agriculture      funded             21  0.509
# 27514     Agriculture      funded             15  0.077
# 27515     Agriculture      funded             13  0.077
# 27516          Retail      funded              6  0.000
# 27517          Retail      funded              8  0.039
# 27518            Food      funded              6  0.062
# 27519            Food      funded             14  0.029
# 27520          Retail      funded         1 Year  0.083
# 27521  Transportation      funded              8  0.039
# 27522          Retail      funded              8  0.497
# 27523            Arts      funded             26  0.077
# 27524     Agriculture      funded             14  0.274
# 27525            Food      funded             15  0.160
# 27526     Agriculture      funded             10  0.054
# 27527            Food      funded             10  0.058
# 27528            Food      funded         1 Year  0.077
# 27529            Food      funded              6  0.062
# 27530  Transportation      funded              6  0.062
# 27531        Services      funded              9  0.158
# 27532     Agriculture      funded              8  0.422
# 27533          Retail      funded             11  0.055
# 27534            Food      funded              6  0.122
# 27535     Agriculture      funded             14  0.033
#
# [27536 rows x 15 columns]

# %%
# How many columns are of ‘object’ data type?
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27536 entries, 0 to 27535
# Data columns (total 15 columns):
# Unnamed: 0            27536 non-null int64
# activity              27535 non-null object
# borrower_genders      27532 non-null object
# country               27534 non-null object
# country_code          27534 non-null object
# currency_policy       27535 non-null object
# distribution_model    27535 non-null object
# lender_count          27534 non-null float64
# loan_amount           27535 non-null float64
# original_language     27533 non-null object
# repayment_interval    27535 non-null object
# sector                27536 non-null object
# status                27536 non-null object
# term_in_months        27536 non-null object
# rMPI                  27536 non-null float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 3.2+ MB

# %%
len(data.select_dtypes('object').columns)
# Out:
# 11

# %%
data.get_dtype_counts()
# Out:
# float64     3
# int64       1
# object     11
# dtype: int64

# %%
# Find the total number of missing values in the data set?
data.isna().sum().sum()
# Out:
# 18

# %%
data.isnull().values.sum()
# Out:
# 18

# %%
# Identify which of the columns contain redundant information 
# and can be dropped from the dataframe.
print(data.distribution_model.unique())
# Out:
# ['field_partner' nan]

# %%
data.distribution_model.value_counts()
# Out:
# field_partner    27535
# Name: distribution_model, dtype: int64

# %%
data.distribution_model.duplicated().value_counts()
# Out:
# True     27534
# False        2
# Name: distribution_model, dtype: int64

# %%
duplicate_percentage = (data.distribution_model.duplicated().sum()*100/data.shape[0])
print("Distribution_model duplicate rows in percentage:",duplicate_percentage)
# Out:
# Distribution_model duplicate rows in percentage: 99.99273678094131

# %%
dup = data.activity.duplicated().value_counts()
print(dup)
# Out:
# True     27385
# False      151
# Name: activity, dtype: int64

# %%
duplicate_percentage1 = (dup[True]*100/data.shape[0])
print("Activity duplicate rows in percentage:",duplicate_percentage1)
# Out:
# Activity duplicate rows in percentage: 99.45162696106915

# %%
data.activity.value_counts()
# Out:
# Farming                      2389
# General Store                2353
# Retail                       1506
# Personal Housing Expenses    1262
# Clothing Sales               1238
# Food Production/Sales        1121
# Agriculture                   907
# Grocery Store                 815
# Home Appliances               797
# Pigs                          735
# Fruits & Vegetables           687
# Higher education costs        625
# Food Market                   599
# Food Stall                    446
# Food                          437
# Fish Selling                  424
# Animal Sales                  372
# Sewing                        347
# Tailoring                     347
# Fishing                       346
# Services                      335
# Personal Expenses             318
# Beauty Salon                  312
# Cattle                        308
# Poultry                       300
# Used Clothing                 299
# Motorcycle Transport          294
# Livestock                     292
# Cosmetics Sales               289
# Cereals                       251
#                              ...
# Blacksmith                     13
# Cheese Making                  13
# Electrician                    12
# Hotel                          12
# Movie Tapes & DVDs             12
# Party Supplies                 11
# Dental                         10
# Bicycle Repair                 10
# Call Center                     8
# Religious Articles              7
# Musical Performance             7
# Child Care                      6
# Music Discs & Tapes             6
# Veterinary Sales                6
# Musical Instruments             6
# Waste Management                5
# Phone Repair                    5
# Machinery Rental                5
# Well digging                    5
# Upholstery                      5
# Secretarial Services            4
# Funerals                        3
# Bicycle Sales                   3
# Machine Shop                    3
# Balut-Making                    3
# Beekeeping                      2
# Sporting Good Sales             2
# Bookbinding                     2
# Aquaculture                     1
# Event Planning                  1
# Name: activity, Length: 150, dtype: int64

# %%
print(data.country_code.unique())
# Out:
# ['KH' 'PH' 'PE' 'TJ' 'UG' 'JO' 'NI' 'NG' 'CO' 'EC' 'HN' 'BJ' 'ID' 'KE'
#  'GT' 'SL' 'SV' 'CD' 'BO' 'SS' nan 'PK' 'TL' 'MN' 'YE' 'CM' 'ML' 'GH' 'NP'
#  'LR' 'LA' 'MZ' 'EG' 'VN' 'ZW' 'SN' 'AF' 'DO' 'BI' 'HT' 'LB' 'RW' 'MW'
#  'US' 'TG' 'IN' 'MG' 'TZ' 'IQ' 'BR' 'CI' 'BF' 'BZ' 'SR' 'CG' 'MM' 'ZM'
#  'GE' 'CR' 'LS' 'KG' 'WS']

# %%
dup1 = data.country_code.duplicated().value_counts()
print(dup1)
# Out:
# True     27474
# False       62
# Name: country_code, dtype: int64

# %%
duplicate_percentage2 = (dup1[True]*100/data.shape[0])
print("Country_code duplicate rows in percentage:",duplicate_percentage2)
# Out:
# Country_code duplicate rows in percentage: 99.77484020918071

# %%
# What is the third quartile value of the variable “loan_amount”?
data['loan_amount'].describe()
# Out:
# count    27535.000000
# mean       792.030143
# std        902.925607
# min         25.000000
# 25%        300.000000
# 50%        550.000000
# 75%       1000.000000
# max      35000.000000
# Name: loan_amount, dtype: float64

# %%
# What is the percentage split of the different categories in the column “repayment_interval” 
# after dropping the missing values?

data.repayment_interval.value_counts()
# Out:
# monthly      15789
# irregular     9264
# bullet        2482
# Name: repayment_interval, dtype: int64

# %%
round(data.repayment_interval.value_counts()*100/data.shape[0])
# Out:
# monthly      57.0
# irregular    34.0
# bullet        9.0
# Name: repayment_interval, dtype: float64

# %%
# What is the minimum loan amount disbursed in the Agriculture sector?
data.groupby('sector')['loan_amount'].max()['Agriculture']
# Out:
# 11025.0
